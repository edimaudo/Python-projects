# %%
#load libraries
import pandas as pd
import numpy as np
import json
from pandas.io.json import json_normalize

# %%
#load data
df = pd.read_json("Issuers.json")

# %%
df.head()
# Out:
#            ISIN           LastChange                 Name  NumPositions  \
# 0  DK0060945467  2019-12-20T00:00:00     5th Planet Games            25
# 1  BMG1466R2078  2019-12-20T00:00:00        Borr Drilling            74
# 2  BMG1738J1247  2019-12-20T00:00:00  BW Offshore Limited            65
# 3  NO0010070063  2019-12-20T00:00:00                  DOF            17
# 4  NO0005052605  2019-12-20T00:00:00          Norsk Hydro            39
#
#                                            Positions  ShortPercent  ShortedSum
# 0  [{'Id': '95929cf8-2a0e-4d9c-8875-c7c2c3a66546'...          0.00           0
# 1  [{'Id': '4d30611c-8ddc-44f3-b1a9-76ead6926a70'...          4.74     5330498
# 2  [{'Id': '62c8c01e-4b26-4845-a3d8-3a119ab22643'...          3.65     6804866
# 3  [{'Id': 'b921eb9a-4932-4e47-ac48-88b76fd3efea'...          1.18     3552000
# 4  [{'Id': '5475f7d5-47dd-4998-893d-45ca31edd92c'...          1.80    37324060

# %%
# Out:
# 0     [{'Id': '95929cf8-2a0e-4d9c-8875-c7c2c3a66546'...
# 1     [{'Id': '4d30611c-8ddc-44f3-b1a9-76ead6926a70'...
# 2     [{'Id': '62c8c01e-4b26-4845-a3d8-3a119ab22643'...
# 3     [{'Id': 'b921eb9a-4932-4e47-ac48-88b76fd3efea'...
# 4     [{'Id': '5475f7d5-47dd-4998-893d-45ca31edd92c'...
# 5     [{'Id': '05867864-0880-443a-9e99-001ec4558e84'...
# 6     [{'Id': 'f81d3047-c2d4-4294-8740-5d5a9431427c'...
# 7     [{'Id': '55a1b4f1-aaf8-4cb7-bb3c-bc793dfb27ac'...
# 8     [{'Id': '9f1f6a1e-cea5-41d3-b3e6-cec605bb2e9c'...
# 9     [{'Id': 'ac900301-1f71-40d9-9060-590de3a99055'...
# 10    [{'Id': '686594c1-2f62-42db-a91f-1dff4ebfcd0b'...
# 11    [{'Id': 'd660f354-f975-40f8-8387-7b6d434ef9e5'...
# 12    [{'Id': 'c01da37b-a2bb-4828-8049-bfd035c3f94c'...
# 13    [{'Id': 'fc5f182d-3942-41e0-bf5c-73ad1c1bf82b'...
# 14    [{'Id': 'c10db516-8dd2-44ea-9bcb-9172cc8e00de'...
# 15    [{'Id': '20e098dd-9a48-49c7-8f93-c864cba97f94'...
# 16    [{'Id': 'b0383ce5-1652-458e-9cb9-257b1e61f82a'...
# ...
