# %%
#load libraries
import pandas as pd
import numpy as np
import seaborn as sns
import warnings
warnings.filterwarnings("ignore")

# %%
df = pd.read_csv('product.csv')

# %%
df.head()
# Out:
#   UTM_Source UTM_Medium Trans_ID  Loan_id  \
# 0        NaN        NaN      NaN       26
# 1        NaN        NaN      NaN       27
# 2        NaN        NaN      NaN       28
# 3        NaN        NaN      NaN       29
# 4        NaN        NaN      NaN       30
#
#                                    uuid Opened_date Closed_date  Product  \
# 0  704ddfea-ba01-4560-8aef-1550932d04d7      1/3/19         NaN  Prime12
# 1  df007477-d209-445a-80e3-649cd1e301d0      1/8/19         NaN  Basic12
# 2  3066d9e8-9575-4fac-88b9-aa0ce2cafc3e     1/10/19     3/26/19  Prime12
# 3  9ef9086b-d671-48f6-a490-9f98152c4ea5     1/11/19         NaN  Prime24
# 4  551f0be6-6264-4636-a864-2da25babe77d     1/14/19     2/12/19  Basic24
#
#   $43,484.00 $43,515.00  ... $43,604.00 $43,635.00 $43,665.00 $43,696.00  \
# 0      $8.95     $10.46  ...      $7.73      $7.14      $2.87      $5.42
# 1      $8.95      $5.25  ...      $3.76      $7.46      $6.96      $3.07
# 2      $8.95     $15.19  ...         $0         $0      $8.95        NaN
# 3      $8.95     $11.86  ...     $10.22     $10.12      $0.41      $9.21
# 4         $0         $0  ...         $0         $0        NaN        NaN
#
#   $43,727.00 $43,757.00 $43,788.00 $43,818.00 $43,485.00 TotalRevenueTodate
# 0      $4.54      $4.01         $0      $9.16        NaN             $72.11
# 1      $2.10         $0      $4.91      $2.89        NaN             $39.89
# 2        NaN        NaN        NaN        NaN        NaN             $27.84
# 3      $8.75      $9.62      $7.83      $7.11        NaN            $105.43
# 4        NaN        NaN        NaN        NaN        NaN                 $0
#
# [5 rows x 22 columns]

# %%
#reduce columns
df = df[['uuid','Opened_date','Product','TotalRevenueTodate']]

# %%
#rename columns
df.columns = ['uuid','Opened_date','Product','Revenue']

# %%
#change opened date
df['Opened_date'] = pd.to_datetime(df['Opened_date'])

# %%
#check for missing data
df.isnull().sum()
# Out:
# uuid           0
# Opened_date    0
# Product        0
# Revenue        0
# dtype: int64

# %%
df['Revenue'] = df['Revenue'].replace({'\$': '', ',': ''}, regex=True).astype(float)

# %%
df.head()
# Out:
#                                    uuid Opened_date  Product  Revenue
# 0  704ddfea-ba01-4560-8aef-1550932d04d7  2019-01-03  Prime12    72.11
# 1  df007477-d209-445a-80e3-649cd1e301d0  2019-01-08  Basic12    39.89
# 2  3066d9e8-9575-4fac-88b9-aa0ce2cafc3e  2019-01-10  Prime12    27.84
# 3  9ef9086b-d671-48f6-a490-9f98152c4ea5  2019-01-11  Prime24   105.43
# 4  551f0be6-6264-4636-a864-2da25babe77d  2019-01-14  Basic24     0.00

# %% [markdown]
# # RFM Model

# %%
import datetime as dt
NOW = dt.datetime(2019,12,20)

# %%
#rfm model
rfmTable = df.groupby('uuid').agg({'Opened_date': lambda x: (NOW - x.max()).days,
                                        'uuid': lambda x: len(x),  
                                        'Revenue': lambda x: x.sum()})

rfmTable['Opened_date'] = rfmTable['Opened_date'].astype(int)
rfmTable.rename(columns={'Opened_date': 'recency', 
                         'uuid': 'frequency', 
                         'Revenue': 'monetary_value'}, inplace=True)
rfmTable.head()
# Out:
#                                       recency  frequency  monetary_value
# uuid
# 0000e106-72fc-4b9d-b0f7-2c54a67982c3       18          1            0.00
# 000acd0f-e9cf-4a71-8069-28cc381c4b2b       79          1            0.00
# 000d12ab-88aa-437c-bb75-3d65ab8767a6      109          1           76.12
# 0018f6d4-ed83-4ac3-a5d9-97e82e15bebd       89          1           37.41
# 001a2dd4-7ab7-4953-b141-11e3ac706611       49          1           45.72

# %%
#split quantiles
quantiles = rfmTable.quantile(q=[0.2,0.4,0.6,0.8])
quantiles = quantiles.to_dict()

# %%
def RScore(x,p,d):
    if x <= d[p][0.20]:
        return 1
    elif x <= d[p][0.40]:
        return 2
    elif x <= d[p][0.60]: 
        return 3
    elif x <= d[p][0.80]: 
        return 4
    else:
        return 5
    
def FMScore(x,p,d):
    if x <= d[p][0.20]:
        return 5
    elif x <= d[p][0.40]:
        return 4
    elif x <= d[p][0.60]: 
        return 3
    elif x <= d[p][0.80]: 
        return 2
    else:
        return 1

# %%
segmented_rfm = rfmTable

# %%
#segment the data
segmented_rfm['r_quartile'] = segmented_rfm['recency'].apply(RScore, args=('recency',quantiles,))
segmented_rfm['f_quartile'] = segmented_rfm['frequency'].apply(FMScore, args=('frequency',quantiles,))
segmented_rfm['m_quartile'] = segmented_rfm['monetary_value'].apply(FMScore, args=('monetary_value',quantiles,))
segmented_rfm.head()
# Out:
#                                       recency  frequency  monetary_value  \
# uuid
# 0000e106-72fc-4b9d-b0f7-2c54a67982c3       18          1            0.00
# 000acd0f-e9cf-4a71-8069-28cc381c4b2b       79          1            0.00
# 000d12ab-88aa-437c-bb75-3d65ab8767a6      109          1           76.12
# 0018f6d4-ed83-4ac3-a5d9-97e82e15bebd       89          1           37.41
# 001a2dd4-7ab7-4953-b141-11e3ac706611       49          1           45.72
#
#                                       r_quartile  f_quartile  m_quartile
# uuid
# 0000e106-72fc-4b9d-b0f7-2c54a67982c3           1           5           5
# 000acd0f-e9cf-4a71-8069-28cc381c4b2b           3           5           5
# 000d12ab-88aa-437c-bb75-3d65ab8767a6           3           5           1
# 0018f6d4-ed83-4ac3-a5d9-97e82e15bebd           3           5           2
# 001a2dd4-7ab7-4953-b141-11e3ac706611           2           5           2

# %%
#add rfm
segmented_rfm['RFMScore'] = segmented_rfm.r_quartile.map(str) + segmented_rfm.f_quartile.map(str) + segmented_rfm.m_quartile.map(str)
segmented_rfm.head()
# Out:
#                                       recency  frequency  monetary_value  \
# uuid
# 0000e106-72fc-4b9d-b0f7-2c54a67982c3       18          1            0.00
# 000acd0f-e9cf-4a71-8069-28cc381c4b2b       79          1            0.00
# 000d12ab-88aa-437c-bb75-3d65ab8767a6      109          1           76.12
# 0018f6d4-ed83-4ac3-a5d9-97e82e15bebd       89          1           37.41
# 001a2dd4-7ab7-4953-b141-11e3ac706611       49          1           45.72
#
#                                       r_quartile  f_quartile  m_quartile  \
# uuid
# 0000e106-72fc-4b9d-b0f7-2c54a67982c3           1           5           5
# 000acd0f-e9cf-4a71-8069-28cc381c4b2b           3           5           5
# 000d12ab-88aa-437c-bb75-3d65ab8767a6           3           5           1
# 0018f6d4-ed83-4ac3-a5d9-97e82e15bebd           3           5           2
# 001a2dd4-7ab7-4953-b141-11e3ac706611           2           5           2
#
#                                      RFMScore
# uuid
# 0000e106-72fc-4b9d-b0f7-2c54a67982c3      155
# 000acd0f-e9cf-4a71-8069-28cc381c4b2b      355
# 000d12ab-88aa-437c-bb75-3d65ab8767a6      351
# 0018f6d4-ed83-4ac3-a5d9-97e82e15bebd      352
# 001a2dd4-7ab7-4953-b141-11e3ac706611      252

# %%
#rfm output
from datetime import date
from datetime import datetime
from datetime import timedelta 

current_time = datetime.now()
info = current_time.strftime('%m%d%Y')
output_filename = ("rfm_" + str(info[:4]) + str(info[6:]) + ".csv")
segmented_rfm.to_csv(output_filename, sep=',', header=True)

# %% [markdown]
# # LTV Model

# %%
segmented_rfm2 = segmented_rfm[['recency','frequency','monetary_value']]

# %%
#rename columns
segmented_rfm2.columns=['num_days','num_transactions','spent_money']
segmented_rfm2.head()
# Out:
#                                       num_days  num_transactions  spent_money
# uuid
# 0000e106-72fc-4b9d-b0f7-2c54a67982c3        18                 1         0.00
# 000acd0f-e9cf-4a71-8069-28cc381c4b2b        79                 1         0.00
# 000d12ab-88aa-437c-bb75-3d65ab8767a6       109                 1        76.12
# 0018f6d4-ed83-4ac3-a5d9-97e82e15bebd        89                 1        37.41
# 001a2dd4-7ab7-4953-b141-11e3ac706611        49                 1        45.72

# %%
#CLTV formula
#CLTV = ((Average Order Value x Purchase Frequency)/Churn Rate) x Profit margin.
#Customer Value = Average Order Value * Purchase Frequency

# %%
# Average Order Value
segmented_rfm2['avg_order_value']=segmented_rfm2['spent_money']/segmented_rfm2['num_transactions']

# %%
purchase_frequency=sum(segmented_rfm2['num_transactions'])/segmented_rfm2.shape[0]

# %%
repeat_rate=segmented_rfm2[segmented_rfm2.num_transactions > 1].shape[0]/segmented_rfm2.shape[0]

# %%
churn_rate=1-repeat_rate

# %%
#assume profit margin is 5%
segmented_rfm2['profit_margin']=1

# %%
# Customer Value
segmented_rfm2['CLV']=(segmented_rfm2['avg_order_value']*purchase_frequency)/churn_rate

# %%
#Customer Lifetime Value
segmented_rfm2['cust_lifetime_value']=segmented_rfm2['CLV']*segmented_rfm2['profit_margin']

# %%
#output ltv model
current_time = datetime.now()
info = current_time.strftime('%m%d%Y')
output_filename = ("ltv_" + str(info[:4]) + str(info[6:]) + ".csv")
segmented_rfm2.to_csv(output_filename, sep=',', header=True)

# %% [markdown]
# # Cohort Analysis

# %%
#cohort is a group of users sharing a particular characteristic. 
#Strictly speaking it can be any characteristic, but typically the term cohort refers to a time-dependent grouping. 
#For example, a typical cohort groups users by the week or month when they were first acquired. 
#When speaking of groupings that are not time-dependent, the term segment is typically used instead of cohort.
#A cohort analysis refers to tracking and investigating the performance of cohorts over time.

# %%
import sklearn
import matplotlib.pyplot as plt
# %matplotlib inline
import warnings
warnings.filterwarnings("ignore")

# %%
#Create a period column based on the giftDate
df['Period'] = df.Opened_date.apply(lambda x: x.strftime('%M'))
df.head(100)
# Out:
#                                     uuid Opened_date    Product  Revenue  \
# 0   704ddfea-ba01-4560-8aef-1550932d04d7  2019-01-03    Prime12    72.11
# 1   df007477-d209-445a-80e3-649cd1e301d0  2019-01-08    Basic12    39.89
# 2   3066d9e8-9575-4fac-88b9-aa0ce2cafc3e  2019-01-10    Prime12    27.84
# 3   9ef9086b-d671-48f6-a490-9f98152c4ea5  2019-01-11    Prime24   105.43
# 4   551f0be6-6264-4636-a864-2da25babe77d  2019-01-14    Basic24     0.00
# 5   1e0e7531-0efe-4a11-bc48-aaa904ad0cad  2019-01-15    Basic24    37.18
# 6   80d77283-d0aa-41bf-9569-2f76649f3c37  2019-01-16    Basic12    17.25
# 7   b2e53e1a-3dfd-4f9b-9486-8ce369737bc0  2019-01-17    Prime12    59.46
# 8   045e3eb9-92b8-4196-af03-8a0805378d4d  2019-01-17    Basic24    37.37
# 9   32116c05-c512-4689-819c-8d6a75a71734  2019-01-17  Premier24   186.18
# 10  81d33043-6aef-4eb1-995b-2fe7e91b55ac  2019-01-18    Prime24   100.83
# 11  2f88da0d-e94e-4046-8638-41221ba80c77  2019-01-21    Basic24    49.33
# 12  09e28f58-236f-4b0d-a63c-25b14856dd42  2019-01-24    Basic12    50.28
# 13  1950e1cf-13c3-49fa-b586-5965b3864f0d  2019-01-28    Basic24    64.93
# 14  272df864-4bd2-42bb-9064-b429ecccae44  2019-01-31    Basic24    49.01
# 87  d6d764bb-a73f-4179-bfeb-3e34497492a3  2019-02-23    Prime12     0.00
# 88  ebc76ac1-67f7-4af7-9470-219c703dfd18  2019-02-23    Basic24    98.48
# 89  e0d1c6ae-70dd-4c68-a9aa-7dfff26f15c1  2019-02-23    Prime12    62.12
# 90  b6a0bb0b-e02f-4378-8ea2-238160b56b30  2019-02-23    Prime24   135.42
# 91  638cbe2d-89dd-4d3b-9be7-30d339677804  2019-02-23    Prime24    80.19
# 92  a899dd49-83f0-481f-971d-8038232df33f  2019-02-23  Premier24   185.04
# 93  4a78745c-5fce-4c19-be99-5d4bdc1805ca  2019-02-23  Premier12   150.92
# 94  f8f26cb9-dd12-4008-bce0-10546c3f8e39  2019-02-23  Premier24   212.41
# 95  de2188ab-5d8d-4509-9487-b8c11c94e61b  2019-02-23    Basic24    32.47
# 96  c6acbbac-cf3d-465d-80e3-fe24d63c073a  2019-02-23    Prime24    43.05
# 97  f1da70c0-198c-45bf-9a1e-ace844a6adb7  2019-02-24  Premier24     0.00
# 98  f7ed1870-2cfa-4318-9106-58b9427fc30a  2019-02-24    Prime24    88.46
# 99  f71102e8-9862-425d-ab26-b128d48138d3  2019-02-24    Prime24   114.86
#
#    Period CohortGroup
# 0      00    01/03/19
# 1      00    01/08/19
# 2      00    01/10/19
# 3      00    01/11/19
# 4      00    01/14/19
# 5      00    01/15/19
# 6      00    01/16/19
# 7      00    01/17/19
# 8      00    01/17/19
# 9      00    01/17/19
# 10     00    01/18/19
# 11     00    01/21/19
# 12     00    01/24/19
# 13     00    01/28/19
# 14     00    01/31/19
# 15     00    01/31/19
# 16     00    02/02/19
# 17     00    02/05/19
# 18     00    02/07/19
# 19     00    02/07/19
# 20     00    02/08/19
# 21     00    02/12/19
# 22     00    02/13/19
# 23     00    02/13/19
# 24     00    02/17/19
# 25     00    02/19/19
# 26     00    02/19/19
# 27     00    02/19/19
# 28     00    02/19/19
# 29     00    02/19/19
# ..    ...         ...
# 70     00    02/22/19
# 71     00    02/22/19
# 72     00    02/22/19
# 73     00    02/22/19
# 74     00    02/22/19
# 75     00    02/22/19
# 76     00    02/22/19
# 77     00    02/22/19
# 78     00    02/22/19
# 79     00    02/23/19
# 80     00    02/23/19
# 81     00    02/23/19
# 82     00    02/23/19
# 83     00    02/23/19
# 84     00    02/23/19
# 85     00    02/23/19
# 86     00    02/23/19
# 87     00    02/23/19
# 88     00    02/23/19
# 89     00    02/23/19
# 90     00    02/23/19
# 91     00    02/23/19
# 92     00    02/23/19
# 93     00    02/23/19
# 94     00    02/23/19
# 95     00    02/23/19
# 96     00    02/23/19
# 97     00    02/24/19
# 98     00    02/24/19
# 99     00    02/24/19
#
# [100 rows x 6 columns]

# %%
#Determine the user's cohort group (based on their first order)
df.set_index('uuid', inplace=True)
df['CohortGroup'] = df.groupby(level=0)['Opened_date'].min().apply(lambda x: x.strftime('%M'))
df.reset_index(inplace=True)
df.head(100)
# Out:
#                                     uuid Opened_date    Product  Revenue  \
# 25     00          00
# 26     00          00
# 27     00          00
# 28     00          00
# 29     00          00
# ..    ...         ...
# 70     00          00
# 71     00          00
# 72     00          00
# 73     00          00
# 74     00          00
# 75     00          00
# 76     00          00
# 77     00          00
# 78     00          00
# 79     00          00
# 80     00          00
# 81     00          00
# 82     00          00
# 83     00          00
# 84     00          00
# 85     00          00
# 86     00          00
# 87     00          00
# 88     00          00
# 89     00          00
# 90     00          00
# 91     00          00
# 92     00          00
# 93     00          00
# 94     00          00
# 95     00          00
# 96     00          00
# 97     00          00
# 98     00          00
# 99     00          00
#
# [100 rows x 6 columns]

# %%
#Rollup data by CohortGroup & OrderPeriod
grouped = df.groupby(['CohortGroup', 'Period'])

# count the unique users, gifttype*, and gift amount + Period
cohorts = grouped.agg({'uuid': pd.Series.nunique,
                       'Revenue': np.sum})

# make the column names more meaningful
cohorts.rename(columns={'uuid': 'TotalUsers'}, inplace=True)
cohorts.head()
# Out:
#                     TotalUsers    Revenue
# CohortGroup Period
# 00          00           10876  377345.51

# %%
#Label the CohortPeriod for each CohortGroup
def cohort_period(df):
    """
    Creates a `CohortPeriod` column, which is the Nth period based on the user's first gift.
    
    Example
    -------
    Say you want to get the 3rd month for every user:
        df.sort(['UserId', 'OrderTime', inplace=True)
        df = df.groupby('UserId').apply(cohort_period)
        df[df.CohortPeriod == 3]
    """
    df['CohortPeriod'] = np.arange(len(df)) + 1
    return df

cohorts = cohorts.groupby(level=0).apply(cohort_period)
cohorts.head()
# Out:
#                     TotalUsers    Revenue  CohortPeriod
# CohortGroup Period
# 00          00           10876  377345.51             1

# %%
#User Retention by Cohort Group
# reindex the DataFrame
cohorts.reset_index(inplace=True)
cohorts.set_index(['CohortGroup', 'CohortPeriod'], inplace=True)

# create a Series holding the total size of each CohortGroup
cohort_group_size = cohorts['TotalUsers'].groupby(level=0).first()
cohort_group_size.head()
# Out:
# CohortGroup
# 00    10876
# Name: TotalUsers, dtype: int64

# %%
cohorts['TotalUsers'].unstack(0).head()
# Out:
# CohortGroup      00
# CohortPeriod
# 1             10876

# %%
user_retention = cohorts['TotalUsers'].unstack(0).divide(cohort_group_size, axis=1)
user_retention.head(10)
# Out:
# CohortGroup    00
# CohortPeriod
# 1             1.0

# %%
#output cohort
current_time = datetime.now()
info = current_time.strftime('%m%d%Y')
output_filename = ("cohort_" + str(info[:4]) + str(info[6:]) + ".csv")
cohorts.to_csv(output_filename, sep=',', header=True)

# %%
#output user rentention
current_time = datetime.now()
info = current_time.strftime('%m%d%Y')
output_filename = ("user_retention_" + str(info[:4]) + str(info[6:]) + ".csv")
user_retention.to_csv(output_filename, sep=',', header=True)

# %%
sns.set(style='white')
plt.figure(figsize=(15, 15))
plt.title('Cohorts: User Retention')
sns.heatmap(user_retention.T, mask=user_retention.T.isnull(), annot=True, fmt='.0%');

# %%
user_retention[['00']].plot(figsize=(10,5))
plt.title('Cohorts: User Retention')
plt.xticks(np.arange(1, 12.1, 1))
plt.xlim(1, 12)
plt.ylabel('% of Retention');
