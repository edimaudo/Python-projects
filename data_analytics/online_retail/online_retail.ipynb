# %%
# Load libraries
import pandas as pd
import numpy as np
import seaborn as sns
import warnings
warnings.filterwarnings("ignore")
# Out:
# /opt/anaconda3/lib/python3.7/site-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %%
# Load data
df = pd.read_excel("Online Retail.xlsx")

# %%
# Take a glimpse of the data
df.head()
# Out:
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                  WHITE METAL LANTERN         6
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#           InvoiceDate  UnitPrice  CustomerID         Country
# 0 2010-12-01 08:26:00       2.55     17850.0  United Kingdom
# 1 2010-12-01 08:26:00       3.39     17850.0  United Kingdom
# 2 2010-12-01 08:26:00       2.75     17850.0  United Kingdom
# 3 2010-12-01 08:26:00       3.39     17850.0  United Kingdom
# 4 2010-12-01 08:26:00       3.39     17850.0  United Kingdom

# %%
# Check for missing information # Missing customer info
df.isnull().sum(axis=0)
# Out:
# InvoiceNo           0
# StockCode           0
# Description      1454
# Quantity            0
# InvoiceDate         0
# UnitPrice           0
# CustomerID     135080
# Country             0
# dtype: int64

# %%
# Check Quantity 
# Looks like negative quantities exist
df.Quantity.min()
# Out:
# -80995

# %%
# Remove missing customer ID
df = df[pd.notnull(df['CustomerID'])]

# %%
# Remove negative quantities
df = df[(df['Quantity']>0)]

# %%
# Add a column for total price
df['TotalPrice'] = df['Quantity'] * df['UnitPrice']

# %%
# Find max date
df['InvoiceDate'].max()
# Out:
# Timestamp('2011-12-09 12:50:00')

# %%
import datetime as dt
NOW = dt.datetime(2011,12,10)
df['InvoiceDate'] = pd.to_datetime(df['InvoiceDate'])

# %%
# RFM model
rfmTable = df.groupby('CustomerID').agg({'InvoiceDate': lambda x: (NOW - x.max()).days,
                                        'InvoiceNo': lambda x: len(x),  
                                        'TotalPrice': lambda x: x.sum()})

rfmTable['InvoiceDate'] = rfmTable['InvoiceDate'].astype(int)
rfmTable.rename(columns={'InvoiceDate': 'recency', 
                         'InvoiceNo': 'frequency', 
                         'TotalPrice': 'monetary_value'}, inplace=True)
rfmTable.head()
# Out:
#             recency  frequency  monetary_value
# CustomerID
# 12346.0         325          1        77183.60
# 12347.0           2        182         4310.00
# 12348.0          75         31         1797.24
# 12349.0          18         73         1757.55
# 12350.0         310         17          334.40

# %%
#split quantiles
quantiles = rfmTable.quantile(q=[0.2,0.4,0.6,0.8])
quantiles = quantiles.to_dict()

# %%
def RScore(x,p,d):
    if x <= d[p][0.20]:
        return 5
    elif x <= d[p][0.40]:
        return 4
    elif x <= d[p][0.60]: 
        return 3
    elif x <= d[p][0.80]: 
        return 2
    else:
        return 1
    
def FMScore(x,p,d):
    if x <= d[p][0.20]:
        return 1
    elif x <= d[p][0.40]:
        return 2
    elif x <= d[p][0.60]: 
        return 3
    elif x <= d[p][0.80]: 
        return 4
    else:
        return 5

# %%
segmented_rfm = rfmTable

# %%
# Score data
segmented_rfm['r_quartile'] = segmented_rfm['recency'].apply(RScore, args=('recency',quantiles,))
segmented_rfm['f_quartile'] = segmented_rfm['frequency'].apply(FMScore, args=('frequency',quantiles,))
segmented_rfm['m_quartile'] = segmented_rfm['monetary_value'].apply(FMScore, args=('monetary_value',quantiles,))
segmented_rfm.head()
# Out:
#             recency  frequency  monetary_value  r_quartile  f_quartile  \
# CustomerID
# 12346.0         325          1        77183.60           1           1
# 12347.0           2        182         4310.00           5           5
# 12348.0          75         31         1797.24           2           3
# 12349.0          18         73         1757.55           4           4
# 12350.0         310         17          334.40           1           2
#
#             m_quartile RFMScore
# CustomerID
# 12346.0              5      515
# 12347.0              5      155
# 12348.0              4      434
# 12349.0              4      244
# 12350.0              2      522

# %%
# RFM Score
segmented_rfm['RFMScore'] = segmented_rfm.r_quartile.map(str) + segmented_rfm.f_quartile.map(str) + segmented_rfm.m_quartile.map(str)
segmented_rfm.head()
# Out:
#             recency  frequency  monetary_value  r_quartile  f_quartile  \
# CustomerID
# 12346.0         325          1        77183.60           1           1
# 12347.0           2        182         4310.00           5           5
# 12348.0          75         31         1797.24           2           3
# 12349.0          18         73         1757.55           4           4
# 12350.0         310         17          334.40           1           2
#
#             m_quartile RFMScore
# CustomerID
# 12346.0              5      115
# 12347.0              5      555
# 12348.0              4      234
# 12349.0              4      444
# 12350.0              2      122

# %%
# Segment customers
segmentation_map = {
    r'[1-2][1-2]': 'Hibernating',
    r'[1-2][3-4]': 'At Risk',
    r'[1-2]5': 'Can\'t Loose',
    r'3[1-2]': 'About to Sleep',
    r'33': 'Need Attention',
    r'[3-4][4-5]': 'Loyal Customers',
    r'41': 'Promising',
    r'51': 'New Customers',
    r'[4-5][2-3]': 'Potential Loyalists',
    r'5[4-5]': 'Champions'
}

segmented_rfm['Segment'] = segmented_rfm['r_quartile'].astype(str) + segmented_rfm['f_quartile'].astype(str)
segmented_rfm['Segment'] = segmented_rfm['Segment'].replace(segmentation_map, regex=True)

# %%
# See segmented customers
segmented_rfm.head()
# Out:
#             recency  frequency  monetary_value  r_quartile  f_quartile  \
# CustomerID
# 12346.0         325          1        77183.60           1           1
# 12347.0           2        182         4310.00           5           5
# 12348.0          75         31         1797.24           2           3
# 12349.0          18         73         1757.55           4           4
# 12350.0         310         17          334.40           1           2
#
#             m_quartile RFMScore          Segment
# CustomerID
# 12346.0              5      115      Hibernating
# 12347.0              5      555        Champions
# 12348.0              4      234          At Risk
# 12349.0              4      444  Loyal Customers
# 12350.0              2      122      Hibernating

# %%
# Segmentation Statistics
rfmStats1 = segmented_rfm[["Segment","recency","frequency", "monetary_value"]].groupby("Segment").agg(["mean","median","count", "std"])
rfmStats1.columns = rfmStats1.columns.map('_'.join).str.strip('|')
rfmStats1
# Out:
#                      recency_mean  recency_median  recency_count  recency_std  \
# Segment
# About to Sleep          52.192547            51.5            322    11.057209
# At Risk                165.435852           144.0            569    82.593437
# Can't Loose            143.226190           117.0             84    73.923006
# Champions                5.400990             4.0            606     3.743768
# Hibernating            209.251397           211.0           1074    89.778884
# Loyal Customers         33.206854            29.0            817    15.484023
# Need Attention          51.985366            53.0            205    11.511068
# New Customers            6.421053             7.0             57     3.385618
# Potential Loyalists     15.668699            16.0            492     9.250860
# Promising               22.362832            22.0            113     5.461001
#
#                      frequency_mean  frequency_median  frequency_count  \
# Segment
# About to Sleep            15.987578                16              322
# At Risk                   56.859402                51              569
# Can't Loose              181.666667               156               84
# Champions                289.031353               166              606
# Hibernating               13.589385                13             1074
# Loyal Customers          157.116279               117              817
# Need Attention            41.736585                40              205
# New Customers              7.578947                 8               57
# Potential Loyalists       34.943089                34              492
# Promising                  7.707965                 8              113
#
#                      frequency_std  monetary_value_mean  \
# Segment
# About to Sleep            8.115972           450.997174
# At Risk                  22.655750           996.916872
# Can't Loose              71.000311          2370.705012
# Champions               536.250916          6960.915446
# Hibernating               8.151748           536.535672
# Loyal Customers         121.488208          2845.732852
# Need Attention            8.293565           856.195854
# New Customers             3.990826          3618.697018
# Potential Loyalists      12.614801           915.450409
# Promising                 3.949868           425.633628
#
#                      monetary_value_median  monetary_value_count  \
# Segment
# About to Sleep                     324.685                   322
# At Risk                            747.810                   569
# Can't Loose                       2116.510                    84
# Champions                         2619.805                   606
# Hibernating                        288.300                  1074
# Loyal Customers                   1775.180                   817
# Need Attention                     705.120                   205
# New Customers                      213.960                    57
# Potential Loyalists                604.195                   492
# Promising                          197.640                   113
#
#                      monetary_value_std
# Segment
# About to Sleep               643.749221
# At Risk                     1015.834140
# Can't Loose                 1697.752066
# Champions                  20735.090858
# Hibernating                 3005.946594
# Loyal Customers             6004.584153
# Need Attention               988.663752
# New Customers              22305.203885
# Potential Loyalists         1874.419436
# Promising                    764.078636

# %% [markdown]
# ### Business Questions

# %%
# Best customers
segment_name = "Champions"
best_customers = segmented_rfm[segmented_rfm['Segment']==segment_name]
best_customers.head()
# Out:
#             recency  frequency  monetary_value  r_quartile  f_quartile  \
# CustomerID
# 12378.0         129        219         4008.62           2           5
# 12501.0         336        149         2169.39           1           5
# 12502.0          95        147         3723.87           2           5
# 12520.0          79        152         2634.26           2           5
# 12688.0         113        171         4873.81           2           5
#
#             m_quartile RFMScore      Segment
# CustomerID
# 12378.0              5      255  Can't Loose
# 12501.0              5      155  Can't Loose
# 12502.0              5      255  Can't Loose
# 12520.0              5      255  Can't Loose
# 12688.0              5      255  Can't Loose

# %%
# Who are your loyal customers?
segment_name = "Loyal Customers"
loyal_customers = segmented_rfm[segmented_rfm['Segment']==segment_name]
loyal_customers.head()
# Out:
#             recency  frequency  monetary_value  r_quartile  f_quartile  \
# CustomerID
# 12349.0          18         73         1757.55           4           4
# 12352.0          36         85         2506.04           3           4
# 12356.0          22         59         2811.43           4           4
# 12357.0          33        131         6207.67           3           5
# 12359.0          57        248         6372.58           3           5
#
#             m_quartile RFMScore          Segment
# CustomerID
# 12349.0              4      444  Loyal Customers
# 12352.0              5      345  Loyal Customers
# 12356.0              5      445  Loyal Customers
# 12357.0              5      355  Loyal Customers
# 12359.0              5      355  Loyal Customers

# %%
# Which customers are at the verge of churning?
segment_name = "At Risk"
churn_customers = segmented_rfm[segmented_rfm['Segment']==segment_name]
churn_customers.head()
# Out:
#             recency  frequency  monetary_value  r_quartile  f_quartile  \
# CustomerID
# 12348.0          75         31         1797.24           2           3
# 12354.0         232         58         1079.40           1           3
# 12377.0         315         77         1628.12           1           4
# 12379.0          81         40          852.24           2           3
# 12383.0         184         99         1850.56           1           4
#
#             m_quartile RFMScore  Segment
# CustomerID
# 12348.0              4      234  At Risk
# 12354.0              4      134  At Risk
# 12377.0              4      144  At Risk
# 12379.0              3      233  At Risk
# 12383.0              4      144  At Risk

# %%
# Who has the potential to be converted in more profitable customers?
segment_name = "Potential Loyalists"
possible_conversion_customers = segmented_rfm[segmented_rfm['Segment']==segment_name]
possible_conversion_customers.head()
# Out:
#             recency  frequency  monetary_value  r_quartile  f_quartile  \
# CustomerID
# 12358.0           1         19         1168.06           5           2
# 12374.0          25         33          742.93           4           3
# 12375.0          10         17          457.50           5           2
# 12384.0          28         27          585.27           4           2
# 12421.0          15         45          807.04           4           3
#
#             m_quartile RFMScore              Segment
# CustomerID
# 12358.0              4      524  Potential Loyalists
# 12374.0              3      433  Potential Loyalists
# 12375.0              2      522  Potential Loyalists
# 12384.0              3      423  Potential Loyalists
# 12421.0              3      433  Potential Loyalists

# %%
# Who are lost customers that you don’t need to pay much attention to?
segment_name = "Hibernating"
lost_customers = segmented_rfm[segmented_rfm['Segment']==segment_name]
lost_customers.head()
# Out:
#             recency  frequency  monetary_value  r_quartile  f_quartile  \
# CustomerID
# 12346.0         325          1         77183.6           1           1
# 12350.0         310         17           334.4           1           2
# 12353.0         204          4            89.0           1           1
# 12355.0         214         13           459.4           1           1
# 12361.0         287         10           189.9           1           1
#
#             m_quartile RFMScore      Segment
# CustomerID
# 12346.0              5      115  Hibernating
# 12350.0              2      122  Hibernating
# 12353.0              1      111  Hibernating
# 12355.0              2      112  Hibernating
# 12361.0              1      111  Hibernating

# %%
# Which customers you must retain?
segment_name = "Can't Loose"
must_retain_customers = segmented_rfm[segmented_rfm['Segment']==segment_name]
must_retain_customers.head()
# Out:
#             recency  frequency  monetary_value  r_quartile  f_quartile  \
# CustomerID
# 12378.0         129        219         4008.62           2           5
# 12501.0         336        149         2169.39           1           5
# 12502.0          95        147         3723.87           2           5
# 12520.0          79        152         2634.26           2           5
# 12688.0         113        171         4873.81           2           5
#
#             m_quartile RFMScore      Segment
# CustomerID
# 12378.0              5      255  Can't Loose
# 12501.0              5      155  Can't Loose
# 12502.0              5      255  Can't Loose
# 12520.0              5      255  Can't Loose
# 12688.0              5      255  Can't Loose

# %%
# Which group of customers is most likely to respond to your current campaign?
segment_name = "Promising"
campaign_respond_customers = segmented_rfm[segmented_rfm['Segment']==segment_name]
campaign_respond_customers.head()
# Out:
#             recency  frequency  monetary_value  r_quartile  f_quartile  \
# CustomerID
# 12445.0          22          4          133.40           4           1
# 12504.0          18          9          482.05           4           1
# 12586.0          17         11          196.94           4           1
# 12603.0          21          3          739.20           4           1
# 12618.0          21         11          177.31           4           1
#
#             m_quartile RFMScore    Segment
# CustomerID
# 12445.0              1      411  Promising
# 12504.0              2      412  Promising
# 12586.0              1      411  Promising
# 12603.0              3      413  Promising
# 12618.0              1      411  Promising
